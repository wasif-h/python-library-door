# %% [markdown]
# # Let's Explore `Pandas` - An Awesome Python Library
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Pandas** is a powerful Python library primarily used for data manipulation and analysis. It's built on top of **NumPy** and provides two main data structures: **Series** and **DataFrame**, which are designed to handle structured data intuitively.
#
# `Official Doc` - https://pandas.pydata.org/docs/user_guide/10min.html
#
# `w3school`     - https://www.w3schools.com/python/pandas/pandas_intro.asp
#
# Let's dive into the details of Pandas:
#
# ### 1. **Installing Pandas**
# First, you need to install Pandas (if you haven't already):
# ```bash
# pip install pandas
# ```
#
# ### 2. **Importing Pandas**
# You typically import Pandas using the alias `pd`:
# ```python
# import pandas as pd
# ```
#
# ### 3. **Pandas Data Structures**
#
# #### **Series**
# - A **Series** is a one-dimensional labeled array capable of holding any data type (integer, float, string, etc.). It’s similar to a column in a spreadsheet.
# - Each value in a Series is associated with an index, which makes it easy to access values.
#
# ##### Example:
# ```python
# import pandas as pd
#
# # Creating a Series from a list
# s = pd.Series([1, 3, 5, 7])
# print(s)
#
# # Creating a Series with custom index
# s_custom = pd.Series([1, 3, 5, 7], index=['a', 'b', 'c', 'd'])
# print(s_custom)
# ```
#
# #### **DataFrame**
# - A **DataFrame** is a two-dimensional labeled data structure with columns of potentially different types. It’s similar to a table or a spreadsheet.
# - A DataFrame can be created from various data sources, including lists, dictionaries, and files (like CSV or Excel).
#
# ##### Example:
# ```python
# # Creating a DataFrame from a dictionary
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie'],
#     'Age': [25, 30, 35],
#     'City': ['New York', 'Los Angeles', 'Chicago']
# }
# df = pd.DataFrame(data)
# print(df)
# ```
#
# ### 4. **Reading Data from Files**
# Pandas makes it easy to read data from various file formats like CSV, Excel, etc.
#
# - **CSV files**:
# ```python
# df = pd.read_csv('filename.csv')
# ```
#
# - **Excel files**:
# ```python
# df = pd.read_excel('filename.xlsx')
# ```
#
# - **JSON files**:
# ```python
# df = pd.read_json('filename.json')
# ```
#
# ### 5. **Inspecting Data**
# Once you have a DataFrame, you’ll often want to inspect the data to understand its structure.
#
# - **Viewing the first few rows**:
# ```python
# df.head()  # Default: shows first 5 rows
# ```
#
# - **Viewing the last few rows**:
# ```python
# df.tail()  # Default: shows last 5 rows
# ```
#
# - **Getting basic information**:
# ```python
# df.info()  # Provides a summary of the DataFrame, including data types and missing values
# ```
#
# - **Descriptive statistics**:
# ```python
# df.describe()  # Gives summary statistics (mean, std, min, etc.) for numeric columns
# ```
#
# ### 6. **Indexing and Selecting Data**
#
# #### **Selecting Columns**
# You can select a single column or multiple columns from a DataFrame.
#
# - Single column (returns a Series):
# ```python
# df['Name']
# ```
#
# - Multiple columns (returns a DataFrame):
# ```python
# df[['Name', 'City']]
# ```
#
# #### **Selecting Rows**
# There are multiple ways to select rows in a DataFrame:
#
# - Using the index:
# ```python
# df.loc[0]  # Selects the first row by label/index
# ```
#
# - Using integer-based indexing:
# ```python
# df.iloc[0]  # Selects the first row by integer position
# ```
#
# - Slicing rows:
# ```python
# df.iloc[0:3]  # Selects the first three rows
# ```
#
# ### 7. **Filtering Data**
# You can filter the rows of a DataFrame based on a condition.
#
# ##### Example:
# ```python
# # Filter rows where Age is greater than 30
# df_filtered = df[df['Age'] > 30]
# print(df_filtered)
# ```
#
# You can also filter with multiple conditions using `&` (and), `|` (or).
#
# ##### Example:
# ```python
# # Filter rows where Age > 30 and City is 'Chicago'
# df_filtered = df[(df['Age'] > 30) & (df['City'] == 'Chicago')]
# print(df_filtered)
# ```
#
# ### 8. **Modifying Data**
#
# #### **Adding New Columns**
# You can add new columns to a DataFrame by directly assigning values.
#
# ##### Example:
# ```python
# # Adding a new column 'Salary'
# df['Salary'] = [50000, 60000, 70000]
# print(df)
# ```
#
# #### **Updating Values**
# You can update values in a DataFrame based on conditions or directly by index.
#
# ##### Example:
# ```python
# # Update the 'City' of the first row
# df.loc[0, 'City'] = 'San Francisco'
# print(df)
# ```
#
# #### **Dropping Columns or Rows**
# You can remove columns or rows using `drop()`.
#
# ##### Example:
# - Dropping a column:
# ```python
# df = df.drop(columns=['Salary'])
# print(df)
# ```
#
# - Dropping a row:
# ```python
# df = df.drop(0)  # Drops the first row
# print(df)
# ```
#
# ### 9. **Handling Missing Data**
# Pandas provides tools to handle missing data (NaN values).
#
# - **Checking for missing values**:
# ```python
# df.isnull().sum()  # Shows the number of missing values per column
# ```
#
# - **Filling missing values**:
# ```python
# df.fillna(value=0)  # Fills NaN values with 0
# ```
#
# - **Dropping missing values**:
# ```python
# df.dropna()  # Drops rows with any NaN values
# ```
#
# ### 10. **GroupBy and Aggregation**
# The `groupby()` function is used to group data based on a column and then apply an aggregation function (like sum, mean, count).
#
# ##### Example:
# ```python
# # Group by 'City' and calculate the mean age
# df_grouped = df.groupby('City')['Age'].mean()
# print(df_grouped)
# ```
#
# ### 11. **Sorting Data**
# You can sort the data in a DataFrame by columns using `sort_values()`.
#
# ##### Example:
# ```python
# # Sort by Age in descending order
# df_sorted = df.sort_values(by='Age', ascending=False)
# print(df_sorted)
# ```
#
# ### 12. **Merging and Joining Data**
# You can merge or join two DataFrames, similar to SQL joins.
#
# ##### Example:
# ```python
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
# df2 = pd.DataFrame({'ID': [1, 2, 3], 'Salary': [50000, 60000, 70000]})
#
# # Merge on 'ID'
# df_merged = pd.merge(df1, df2, on='ID')
# print(df_merged)
# ```
#
# ### 13. **Pivot Tables**
# You can create pivot tables to summarize data.
#
# ##### Example:
# ```python
# df = pd.DataFrame({
#     'City': ['New York', 'Chicago', 'New York', 'Chicago'],
#     'Sales': [200, 150, 300, 250]
# })
#
# # Create a pivot table showing the sum of Sales by City
# pivot_table = df.pivot_table(values='Sales', index='City', aggfunc='sum')
# print(pivot_table)
# ```
#
# ### 14. **Exporting Data**
# You can export a DataFrame to various formats, such as CSV, Excel, or JSON.
#
# - **To CSV**:
# ```python
# df.to_csv('output.csv', index=False)
# ```
#
# - **To Excel**:
# ```python
# df.to_excel('output.xlsx', index=False)
# ```
#
# ### 15. **Advanced Operations**
#
# #### **Apply Functions**
# You can apply custom functions to columns or rows using the `apply()` function.
#
# ##### Example:
# ```python
# # Apply a custom function to the 'Age' column
# df['Age_in_5_years'] = df['Age'].apply(lambda x: x + 5)
# print(df)
# ```
#
# #### **Window Functions**
# Pandas supports rolling window operations, which are useful for time series analysis.
#
# ##### Example:
# ```python
# # Rolling mean over 2 periods
# df['Rolling_mean'] = df['Sales'].rolling(window=2).mean()
# print(df)
# ```
#
# ---

# %% [markdown]
# # Practice and Special Notes

# %%
import pandas as pd
import numpy as np

# %%
company_info = {
    'Name' : ["Wasif","Galib","Hasib"],
    'Age'  : [23,21,26],
    'Salary' : [120000,45000,34000]
}
df = pd.DataFrame(company_info)
print(df)
# Out:
#     Name  Age  Salary
# 0  Wasif   23  120000
# 1  Galib   21   45000
# 2  Hasib   26   34000

# %%
nums = np.random.randint(1,100,size=[30,5])
ndf = pd.DataFrame(nums, columns=["A",'B','C','D','E'], index=[x for x in range(1,31)])
print(ndf.head())
# Out:
#     A   B   C   D   E
# 1  21  24   8  36   8
# 2  35  51   3  13  90
# 3  15  60  85  74  11
# 4  92  20  32  16  92
# 5  88  41  45  26  93

# %%
# to get ta data type, null value, size, shape
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       30 non-null     int32
#  1   B       30 non-null     int32
#  2   C       30 non-null     int32
#  3   D       30 non-null     int32
#  4   E       30 non-null     int32
# dtypes: int32(5)
# memory usage: 840.0 bytes

# %%
# to find the avg, min , max
ndf.describe()
# Out:
#                A          B          C          D          E
# count  30.000000  30.000000  30.000000  30.000000  30.000000
# mean   56.366667  41.700000  45.766667  43.900000  55.833333
# std    28.923780  26.797002  25.110354  28.622815  29.502873
# min    10.000000   5.000000   2.000000   3.000000   8.000000
# 25%    34.250000  20.000000  24.250000  16.500000  32.000000
# 50%    53.000000  43.000000  46.500000  42.500000  61.500000
# 75%    82.250000  59.750000  62.500000  71.500000  79.500000
# max    99.000000  91.000000  87.000000  92.000000  95.000000

# %%
ndf.shape
# Out:
# (30, 5)

# %%
# to find the unique values in a column
ndf['A'].unique()
# Out:
# array([21, 35, 15, 92, 88, 57, 72, 79, 80, 43, 85, 34, 48, 38, 20, 91, 98,
#        42, 99, 18, 44, 16, 65, 27, 49, 76, 10, 74, 83])

# %%
# parquet file is the most efficient file format based on size and speed
res = pd.read_parquet("../dataset/results.parquet")
res
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied medal
# 0        True  None
# 1       False  None
# 2        True  None
# 3        True  None
# 4       False  None
# ...       ...   ...
# 308403  False  None
# 308404  False  None
# 308405  False  None
# 308406  False  None
# 308407  False  None
#
# [308408 rows x 11 columns]

# %%
res.head(3) # head -> first n num rows    tail -> last n num rows
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis  Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc            team  place   tied medal
# 0           1  FRA            None   17.0   True  None
# 1           1  FRA  Jean Montariol    NaN  False  None
# 2           1  FRA            None   32.0   True  None

# %%
# giving a sample of random rows
res.sample(5)
# Out:
#           year    type                        discipline  \
# 229955  2004.0  Summer                         Athletics
# 47459   1996.0  Summer               Football (Football)
# 261449  2016.0  Summer               Swimming (Aquatics)
# 69613   1948.0  Summer  Artistic Gymnastics (Gymnastics)
# 215314  1998.0  Winter             Bobsleigh (Bobsleigh)
#
#                                      event              as  athlete_id  noc  \
# 229955          Long Jump, Women (Olympic)  Alina Militaru      106540  ROU
# 47459              Football, Men (Olympic)   Aitor Karanka       24906  ESP
# 261449  50 metres Freestyle, Men (Olympic)  Andriy Hovorov      121502  UKR
# 69613        Floor Exercise, Men (Olympic)     Emil Studer       31047  SUI
# 215314                 Four, Men (Olympic)  Edin Krupalija       99942  BIH
#
#                           team  place   tied medal
# 229955                    None    1.0  False  None
# 47459                    Spain    6.0  False  None
# 261449                    None    5.0  False  None
# 69613                     None   41.0   True  None
# 215314  Bosnia and Herzegovina   25.0  False  None

# %%
res
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied medal
# 0        True  None
# 1       False  None
# 2        True  None
# 3        True  None
# 4       False  None
# ...       ...   ...
# 308403  False  None
# 308404  False  None
# 308405  False  None
# 308406  False  None
# 308407  False  None
#
# [308408 rows x 11 columns]

# %%
# loc - name based filter -> arr.loc[[rows names],[cols names]]
res.loc[[1,2,3,4],['year','type']]
# Out:
#      year    type
# 1  1912.0  Summer
# 2  1920.0  Summer
# 3  1920.0  Summer
# 4  1920.0  Summer

# %%
# iloc - index based filter -> arr.iloc[[rows index],[cols index]]
res.iloc[0:5,[0,1,6]]
# Out:
#      year    type  noc
# 0  1912.0  Summer  FRA
# 1  1912.0  Summer  FRA
# 2  1920.0  Summer  FRA
# 3  1920.0  Summer  FRA
# 4  1920.0  Summer  FRA

# %%
# if i change the index of rows into manual index then i must have use loc
res.index = res['type']
res.head()
# Out:
#           year    type discipline                     event  \
# type
# Summer  1912.0  Summer     Tennis    Singles, Men (Olympic)
# Summer  1912.0  Summer     Tennis    Doubles, Men (Olympic)
# Summer  1920.0  Summer     Tennis    Singles, Men (Olympic)
# Summer  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)
# Summer  1920.0  Summer     Tennis    Doubles, Men (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# type
# Summer  Jean-François Blanchy           1  FRA             None   17.0   True
# Summer  Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# Summer  Jean-François Blanchy           1  FRA             None   32.0   True
# Summer  Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# Summer  Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
#
#        medal
# type
# Summer  None
# Summer  None
# Summer  None
# Summer  None
# Summer  None

# %%
res.loc["Summer",['year','type','event']]
# Out:
#           year    type                       event
# type
# Summer  1912.0  Summer      Singles, Men (Olympic)
# Summer  1912.0  Summer      Doubles, Men (Olympic)
# Summer  1920.0  Summer      Singles, Men (Olympic)
# Summer  1920.0  Summer    Doubles, Mixed (Olympic)
# Summer  1920.0  Summer      Doubles, Men (Olympic)
# ...        ...     ...                         ...
# Summer  1996.0  Summer   Water Polo, Men (Olympic)
# Summer  1920.0  Summer  Coxed Fours, Men (Olympic)
# Summer  2018.0  Summer        Combined, Boys (YOG)
# Summer  2018.0  Summer         Sprint, Girls (YOG)
# Summer  2018.0  Summer    Relay, Mixed Youth (YOG)
#
# [241298 rows x 3 columns]

# %%
# Changed value using loc function
res.loc["Summer",['event']] = "Changed Value"
res.head(10)
# Out:
#           year    type discipline          event                     as  \
# type
# Summer  1912.0  Summer     Tennis  Changed Value  Jean-François Blanchy
# Summer  1912.0  Summer     Tennis  Changed Value  Jean-François Blanchy
# Summer  1920.0  Summer     Tennis  Changed Value  Jean-François Blanchy
# Summer  1920.0  Summer     Tennis  Changed Value  Jean-François Blanchy
# Summer  1920.0  Summer     Tennis  Changed Value  Jean-François Blanchy
# Summer  1996.0  Summer     Tennis  Changed Value         Arnaud Boetsch
# Summer  1996.0  Summer     Tennis  Changed Value         Arnaud Boetsch
# Summer  1924.0  Summer     Tennis  Changed Value           Jean Borotra
# Summer  1924.0  Summer     Tennis  Changed Value           Jean Borotra
# Summer  1924.0  Summer     Tennis  Changed Value           Jean Borotra
#
#         athlete_id  noc                team  place   tied   medal
# type
# Summer           1  FRA                None   17.0   True    None
# Summer           1  FRA      Jean Montariol    NaN  False    None
# Summer           1  FRA                None   32.0   True    None
# Summer           1  FRA     Jeanne Vaussard    8.0   True    None
# Summer           1  FRA     Jacques Brugnon    4.0  False    None
# Summer           2  FRA                None   17.0   True    None
# Summer           2  FRA     Guillaume Raoux   17.0   True    None
# Summer           3  FRA                None    4.0  False    None
# Summer           3  FRA  Marguerite Billout   15.0   True    None
# Summer           3  FRA        René Lacoste    3.0  False  Bronze

# %% [markdown]
# ### Sort Values

# %%
res.sort_values(['year'])
# Out:
#           year    type           discipline                             event  \
# type
# Summer  1896.0  Summer            Athletics                     Changed Value
# Summer  1896.0  Summer            Athletics                     Changed Value
# Summer  1896.0  Summer            Athletics                     Changed Value
# Summer  1896.0  Summer            Athletics                     Changed Value
# Summer  1896.0  Summer            Athletics                     Changed Value
# ...        ...     ...                  ...                               ...
# None       NaN    None              Fencing  Sabre, Individual, Men (Olympic)
# None       NaN    None              Fencing        Sabre, Team, Men (Olympic)
# None       NaN    None  Football (Football)      Football, Men (Intercalated)
# None       NaN    None  Football (Football)      Football, Men (Intercalated)
# None       NaN    None    Diving (Aquatics)      Platform, Men (Intercalated)
#
#                           as  athlete_id  noc     team  place   tied   medal
# type
# Summer           Nándor Dáni       71127  HUN     None    NaN  False    None
# Summer  Georgios Papasideris       70824  GRE     None    3.0  False  Bronze
# Summer            Tom Curtis       78290  USA     None    NaN  False    None
# Summer            Tom Curtis       78290  USA     None    1.0  False    Gold
# Summer            Tom Curtis       78290  USA     None    1.0  False    None
# ...                      ...         ...  ...      ...    ...    ...     ...
# None         Lóránt Mészáros       95189  HUN     None    5.0  False    None
# None         Lóránt Mészáros       95189  HUN  Hungary    4.0  False    None
# None         Georgios Pantos      100811  GRE   Athens    NaN  False    None
# None    Alexandros Kalafatis      100812  GRE   Athens    NaN  False    None
# None        Wilhelm Lindgren      127259  SWE     None   13.0  False    None
#
# [308408 rows x 11 columns]

# %%
res.sort_values(['year'],ascending=False)
# Out:
#           year    type               discipline  \
# type
# Winter  2022.0  Winter                     None
# Winter  2022.0  Winter  Ice Hockey (Ice Hockey)
# Winter  2022.0  Winter  Ice Hockey (Ice Hockey)
# Winter  2022.0  Winter  Ice Hockey (Ice Hockey)
# Winter  2022.0  Winter    Bobsleigh (Bobsleigh)
# ...        ...     ...                      ...
# None       NaN    None                  Fencing
# None       NaN    None                  Fencing
# None       NaN    None      Football (Football)
# None       NaN    None      Football (Football)
# None       NaN    None        Diving (Aquatics)
#
#                                    event                    as  athlete_id  \
# type
# Winter           Slalom, Women (Olympic)  Charlotta Säfvenberg      148986
# Winter         Ice Hockey, Men (Olympic)        Ronalds Ķēniņš      128130
# Winter         Ice Hockey, Men (Olympic)   Kristers Gudļevskis      128127
# Winter         Ice Hockey, Men (Olympic)       Ralfs Freibergs      128125
# Winter              Four, Open (Olympic)     Oskars Ķibermanis      128118
# ...                                  ...                   ...         ...
# None    Sabre, Individual, Men (Olympic)       Lóránt Mészáros       95189
# None          Sabre, Team, Men (Olympic)       Lóránt Mészáros       95189
# None        Football, Men (Intercalated)       Georgios Pantos      100811
# None        Football, Men (Intercalated)  Alexandros Kalafatis      100812
# None        Platform, Men (Intercalated)      Wilhelm Lindgren      127259
#
#          noc      team  place   tied medal
# type
# Winter  None      None   24.0  False  None
# Winter   LAT    Latvia   11.0  False  None
# Winter   LAT    Latvia    NaN  False  None
# Winter   LAT    Latvia   11.0  False  None
# Winter   LAT  Latvia 1    5.0  False  None
# ...      ...       ...    ...    ...   ...
# None     HUN      None    5.0  False  None
# None     HUN   Hungary    4.0  False  None
# None     GRE    Athens    NaN  False  None
# None     GRE    Athens    NaN  False  None
# None     SWE      None   13.0  False  None
#
# [308408 rows x 11 columns]

# %%
#another way of sorting
res[res["type"] == "Winter"].sort_values(by=["year","discipline"],ascending=False)
# Out:
#           year    type               discipline  \
# type
# Winter  2022.0  Winter  Speed Skating (Skating)
# Winter  2022.0  Winter  Speed Skating (Skating)
# Winter  2022.0  Winter  Speed Skating (Skating)
# Winter  2022.0  Winter  Speed Skating (Skating)
# Winter  2022.0  Winter  Speed Skating (Skating)
# ...        ...     ...                      ...
# Winter  1924.0  Winter    Bobsleigh (Bobsleigh)
# Winter  1924.0  Winter    Bobsleigh (Bobsleigh)
# Winter  1924.0  Winter    Bobsleigh (Bobsleigh)
# Winter  1924.0  Winter    Bobsleigh (Bobsleigh)
# Winter  1924.0  Winter    Bobsleigh (Bobsleigh)
#
#                                        event                  as  athlete_id  \
# type
# Winter         3,000 metres, Women (Olympic)   Claudia Pechstein       82053
# Winter           Mass Start, Women (Olympic)   Claudia Pechstein       82053
# Winter           5,000 metres, Men (Olympic)         Sven Kramer      109681
# Winter             Mass Start, Men (Olympic)         Sven Kramer      109681
# Winter  Team Pursuit (8 laps), Men (Olympic)         Sven Kramer      109681
# ...                                      ...                 ...         ...
# Winter              Four/Five, Men (Olympic)  Victor Verschueren       98621
# Winter               Ice Hockey (Ice Hockey)  Victor Verschueren       98621
# Winter             Ice Hockey, Men (Olympic)  Victor Verschueren       98621
# Winter              Four/Five, Men (Olympic)    Alberto Visconti       98666
# Winter              Four/Five, Men (Olympic)       Henri Willems       98964
#
#         noc         team  place   tied   medal
# type
# Winter  GER         None   20.0  False    None
# Winter  GER         None    9.0  False    None
# Winter  NED         None    9.0  False    None
# Winter  NED         None   16.0  False    None
# Winter  NED  Netherlands    4.0  False    None
# ...     ...          ...    ...    ...     ...
# Winter  BEL    Belgium 1    3.0  False  Bronze
# Winter  BEL          BEL    NaN   True    None
# Winter  BEL      Belgium    7.0   True    None
# Winter  ITA      Italy 2    NaN  False    None
# Winter  BEL    Belgium 1    3.0  False  Bronze
#
# [64509 rows x 11 columns]

# %% [markdown]
# # Filtering Data

# %%
bios = pd.read_csv("../dataset/bios.csv")
bios.sample(10)
# Out:
#         athlete_id                          name   born_date   born_city  \
# 98971        99767                   Jana Šedová  1974-01-16  Bratislava
# 84259        84930                 Antenore Cuel  1922-03-27    Folgaria
# 42463        42786              Kornél Marosvári  1943-06-30        Baja
# 130915      133669                 Sergio García  1980-01-09     Borriol
# 60498        60933  Cristina, Princesa de Borbón  1965-06-13      Madrid
# 38270        38572               Kinichiro Ishii         NaN         NaN
# 7422          7462              Alexander Decker  1904-02-02         NaN
# 86305        86992                    William To  1979-08-07         NaN
# 80262        80913                 Jadwiga Damse  1947-09-05       Nisko
# 141274      144814              Elizabeth Akinyi  1993-09-25     Nairobi
#
#          born_region born_country               NOC  height_cm  weight_kg  \
# 98971     Bratislava          SVK          Slovakia      165.0       57.0
# 84259         Trento          ITA             Italy        NaN        NaN
# 42463    Bács-Kiskun          HUN           Hungary      181.0       74.0
# 130915     Castellón          ESP             Spain      178.0        NaN
# 60498         Madrid          ESP             Spain      176.0       65.0
# 38270            NaN          NaN             Japan        NaN        NaN
# 7422             NaN          NaN           Austria        NaN        NaN
# 86305            NaN          NaN  Hong Kong, China      175.0       66.0
# 80262   Podkarpackie          POL            Poland      165.0       69.0
# 141274       Nairobi          KEN             Kenya        NaN        NaN
#
#          died_date
# 98971          NaN
# 84259   2018-02-21
# 42463   2016-05-30
# 130915         NaN
# 60498          NaN
# 38270          NaN
# 7422           NaN
# 86305          NaN
# 80262          NaN
# 141274         NaN

# %%
# syntex -> arr[arr[rows] filter condition][[column names passsing in a list]]

aus = bios[(bios["NOC"] == "Australia") & (bios["weight_kg"] > 90 )][["athlete_id","name","NOC"]]
aus.head()
# Out:
#       athlete_id                name        NOC
# 300          301        Jackson Fear  Australia
# 631          634  Mark Philippoussis  Australia
# 1464        1471         David Hynes  Australia
# 1465        1472       Sten Lindberg  Australia
# 1473        1480     Stuart Thompson  Australia

# %%
bios[bios["name"].str.contains("tony", case=False)]
# Out:
#         athlete_id             name   born_date      born_city born_region  \
# 1017          1021        Tony Mmoh  1958-06-14          Enugu       Enugu
# 1199          1206     Tony Mancini  1913-01-17       Montréal      Québec
# 3519          3531      Tony Willis  1960-06-17      Liverpool     England
# 3521          3533      Tony Wilson  1961-04-15  Wolverhampton     England
# 3687          3699      Tony Martey  1944-06-23          Aflao       Volta
# ...            ...              ...         ...            ...         ...
# 132541      135417       Tony Dodds  1987-06-16      Balclutha       Otago
# 137845      141224           Antony  2000-02-24         Osasco   São Paulo
# 140246      143749      Alex Antony  1994-09-03            NaN         NaN
# 141963      145550  Tony van Diepen  1996-04-17            NaN         NaN
# 142023      145616  Atonye Nyingifa  1990-12-08            NaN         NaN
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 1017            NGR        Nigeria      177.0       81.0         NaN
# 1199            CAN         Canada        NaN        NaN  1990-08-19
# 3519            GBR  Great Britain      170.0       64.0         NaN
# 3521            GBR  Great Britain      180.0       81.0         NaN
# 3687            GHA          Ghana      160.0       60.0         NaN
# ...             ...            ...        ...        ...         ...
# 132541          NZL    New Zealand      183.0       68.0         NaN
# 137845          BRA         Brazil      174.0       63.0         NaN
# 140246          NaN          India        NaN        NaN         NaN
# 141963          NaN    Netherlands        NaN        NaN         NaN
# 142023          NaN        Nigeria        NaN        NaN         NaN
#
# [176 rows x 10 columns]

# %%
country = ['GBR','CAN','USA']
bios[bios["born_country"].isin(country)][["name","born_city"]]
# Out:
#                      name      born_city
# 4            Albert Canet     Wandsworth
# 37        Helen Aitchison     Sunderland
# 38      Geraldine Beamish    Forest Gate
# 39           Dora Boothby       Finchley
# 40         Julie Bradbury         Oxford
# ...                   ...            ...
# 145457     Alix Wilkinson  Mammoth Lakes
# 145461       Kent Johnson     Port Moody
# 145462       Morgan Ellis     Summerside
# 145468  Justin Abdelkader       Muskegon
# 145494      George Wright        Toronto
#
# [20049 rows x 2 columns]

# %%
# another ways of filtering 
bios2 = bios.set_index("NOC")
bios2.head()
# Out:
#         athlete_id                   name   born_date    born_city  \
# NOC
# France           1  Jean-François Blanchy  1886-12-12     Bordeaux
# France           2         Arnaud Boetsch  1969-04-01       Meulan
# France           3           Jean Borotra  1898-08-13     Biarritz
# France           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# France           5           Albert Canet  1878-04-17   Wandsworth
#
#                  born_region born_country  height_cm  weight_kg   died_date
# NOC
# France               Gironde          FRA        NaN        NaN  1960-10-02
# France              Yvelines          FRA      183.0       76.0         NaN
# France  Pyrénées-Atlantiques          FRA      183.0       76.0  1994-07-17
# France                 Paris          FRA      168.0       64.0  1978-03-20
# France               England          GBR        NaN        NaN  1930-07-25

# %%
bios2.filter(like="United", axis=0) #default axis 1
# Out:
#                                           athlete_id  \
# NOC
# Georgia Unified Team United States               504
# People's Republic of China United States         783
# United States                                   1352
# United States                                   1353
# United States                                   1363
# ...                                              ...
# United States                                 149169
# United States                                 149170
# United States                                 149180
# United States                                 149183
# United States                                 149195
#
#                                                                 name  \
# NOC
# Georgia Unified Team United States        Khatuna Kvrivishvili-Lorig
# People's Republic of China United States                     Jun Gao
# United States                                             Laura Berg
# United States                                           Gillian Boxx
# United States                                   Sheila Cornell-Douty
# ...                                                              ...
# United States                                       Corinne Stoddard
# United States                                             Andrew Heo
# United States                                          Anna Hoffmann
# United States                                         Alix Wilkinson
# United States                                      Justin Abdelkader
#
#                                            born_date         born_city  \
# NOC
# Georgia Unified Team United States        1974-01-01           Tbilisi
# People's Republic of China United States  1969-01-25           Baoding
# United States                             1975-01-06  Santa Fe Springs
# United States                             1973-09-01           Fontana
# United States                             1962-02-26            Encino
# ...                                              ...               ...
# United States                             2001-08-15           Seattle
# United States                             2001-03-07               NaN
# United States                             2000-03-28           Madison
# United States                             2000-08-02     Mammoth Lakes
# United States                             1987-02-25          Muskegon
#
#                                          born_region born_country  height_cm  \
# NOC
# Georgia Unified Team United States           Tbilisi          GEO      170.0
# People's Republic of China United States       Hebei          CHN      168.0
# United States                             California          USA      168.0
# United States                             California          USA      170.0
# United States                             California          USA      175.0
# ...                                              ...          ...        ...
# United States                             Washington          USA        NaN
# United States                                    NaN          NaN        NaN
# United States                              Wisconsin          USA        NaN
# United States                             California          USA        NaN
# United States                               Michigan          USA      187.0
#
#                                           weight_kg died_date
# NOC
# Georgia Unified Team United States             64.0       NaN
# People's Republic of China United States       73.0       NaN
# United States                                  61.0       NaN
# United States                                   NaN       NaN
# United States                                  81.0       NaN
# ...                                             ...       ...
# United States                                   NaN       NaN
# United States                                   NaN       NaN
# United States                                   NaN       NaN
# United States                                   NaN       NaN
# United States                                  97.0       NaN
#
# [10603 rows x 9 columns]

# %%
bios2.filter(items=['name','born_date'])
# Out:
#                             name   born_date
# NOC
# France     Jean-François Blanchy  1886-12-12
# France            Arnaud Boetsch  1969-04-01
# France              Jean Borotra  1898-08-13
# France           Jacques Brugnon  1895-05-11
# France              Albert Canet  1878-04-17
# ...                          ...         ...
# ROC            Polina Luchnikova  2002-01-30
# ROC          Valeriya Merkusheva  1999-09-20
# ROC              Yuliya Smirnova  1998-05-08
# France            André Foussard  1899-05-19
# Australia          Bill Phillips  1913-07-15
#
# [145500 rows x 2 columns]

# %% [markdown]
# # Indexing

# %%
bios.set_index("name",inplace=True)
bios
# Out:
#                        athlete_id   born_date        born_city  \
# name
# Jean-François Blanchy           1  1886-12-12         Bordeaux
# Arnaud Boetsch                  2  1969-04-01           Meulan
# Jean Borotra                    3  1898-08-13         Biarritz
# Jacques Brugnon                 4  1895-05-11      Paris VIIIe
# Albert Canet                    5  1878-04-17       Wandsworth
# ...                           ...         ...              ...
# Polina Luchnikova          149222  2002-01-30            Serov
# Valeriya Merkusheva        149223  1999-09-20  Moskva (Moscow)
# Yuliya Smirnova            149224  1998-05-08           Kotlas
# André Foussard             149225  1899-05-19            Niort
# Bill Phillips              149814  1913-07-15     Dulwich Hill
#
#                                 born_region born_country        NOC  \
# name
# Jean-François Blanchy               Gironde          FRA     France
# Arnaud Boetsch                     Yvelines          FRA     France
# Jean Borotra           Pyrénées-Atlantiques          FRA     France
# Jacques Brugnon                       Paris          FRA     France
# Albert Canet                        England          GBR     France
# ...                                     ...          ...        ...
# Polina Luchnikova                Sverdlovsk          RUS        ROC
# Valeriya Merkusheva                  Moskva          RUS        ROC
# Yuliya Smirnova                 Arkhangelsk          RUS        ROC
# André Foussard                  Deux-Sèvres          FRA     France
# Bill Phillips               New South Wales          AUS  Australia
#
#                        height_cm  weight_kg   died_date
# name
# Jean-François Blanchy        NaN        NaN  1960-10-02
# Arnaud Boetsch             183.0       76.0         NaN
# Jean Borotra               183.0       76.0  1994-07-17
# Jacques Brugnon            168.0       64.0  1978-03-20
# Albert Canet                 NaN        NaN  1930-07-25
# ...                          ...        ...         ...
# Polina Luchnikova          167.0       61.0         NaN
# Valeriya Merkusheva        168.0       65.0         NaN
# Yuliya Smirnova            163.0       55.0         NaN
# André Foussard             166.0        NaN  1986-03-18
# Bill Phillips                NaN        NaN  2003-10-20
#
# [145500 rows x 9 columns]

# %%
bios.reset_index(inplace=True)
bios
# Out:
#                          name  athlete_id   born_date        born_city  \
# 0       Jean-François Blanchy           1  1886-12-12         Bordeaux
# 1              Arnaud Boetsch           2  1969-04-01           Meulan
# 2                Jean Borotra           3  1898-08-13         Biarritz
# 3             Jacques Brugnon           4  1895-05-11      Paris VIIIe
# 4                Albert Canet           5  1878-04-17       Wandsworth
# ...                       ...         ...         ...              ...
# 145495      Polina Luchnikova      149222  2002-01-30            Serov
# 145496    Valeriya Merkusheva      149223  1999-09-20  Moskva (Moscow)
# 145497        Yuliya Smirnova      149224  1998-05-08           Kotlas
# 145498         André Foussard      149225  1899-05-19            Niort
# 145499          Bill Phillips      149814  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
# composite key or index

bios.set_index(["born_country","born_region"],inplace=True)
bios
# Out:
#                                                     name  athlete_id  \
# born_country born_region
# FRA          Gironde               Jean-François Blanchy           1
#              Yvelines                     Arnaud Boetsch           2
#              Pyrénées-Atlantiques           Jean Borotra           3
#              Paris                       Jacques Brugnon           4
# GBR          England                        Albert Canet           5
# ...                                                  ...         ...
# RUS          Sverdlovsk                Polina Luchnikova      149222
#              Moskva                  Valeriya Merkusheva      149223
#              Arkhangelsk                 Yuliya Smirnova      149224
# FRA          Deux-Sèvres                  André Foussard      149225
# AUS          New South Wales               Bill Phillips      149814
#
#                                     born_date        born_city        NOC  \
# born_country born_region
# FRA          Gironde               1886-12-12         Bordeaux     France
#              Yvelines              1969-04-01           Meulan     France
#              Pyrénées-Atlantiques  1898-08-13         Biarritz     France
#              Paris                 1895-05-11      Paris VIIIe     France
# GBR          England               1878-04-17       Wandsworth     France
# ...                                       ...              ...        ...
# RUS          Sverdlovsk            2002-01-30            Serov        ROC
#              Moskva                1999-09-20  Moskva (Moscow)        ROC
#              Arkhangelsk           1998-05-08           Kotlas        ROC
# FRA          Deux-Sèvres           1899-05-19            Niort     France
# AUS          New South Wales       1913-07-15     Dulwich Hill  Australia
#
#                                    height_cm  weight_kg   died_date
# born_country born_region
# FRA          Gironde                     NaN        NaN  1960-10-02
#              Yvelines                  183.0       76.0         NaN
#              Pyrénées-Atlantiques      183.0       76.0  1994-07-17
#              Paris                     168.0       64.0  1978-03-20
# GBR          England                     NaN        NaN  1930-07-25
# ...                                      ...        ...         ...
# RUS          Sverdlovsk                167.0       61.0         NaN
#              Moskva                    168.0       65.0         NaN
#              Arkhangelsk               163.0       55.0         NaN
# FRA          Deux-Sèvres               166.0        NaN  1986-03-18
# AUS          New South Wales             NaN        NaN  2003-10-20
#
# [145500 rows x 8 columns]

# %%
# sort index 
bios.sort_index(ascending=[False,False])
bios.head()
# Out:
#                                                     name  athlete_id  \
# born_country born_region
# FRA          Gironde               Jean-François Blanchy           1
#              Yvelines                     Arnaud Boetsch           2
#              Pyrénées-Atlantiques           Jean Borotra           3
#              Paris                       Jacques Brugnon           4
# GBR          England                        Albert Canet           5
#
#                                     born_date    born_city     NOC  height_cm  \
# born_country born_region
# FRA          Gironde               1886-12-12     Bordeaux  France        NaN
#              Yvelines              1969-04-01       Meulan  France      183.0
#              Pyrénées-Atlantiques  1898-08-13     Biarritz  France      183.0
#              Paris                 1895-05-11  Paris VIIIe  France      168.0
# GBR          England               1878-04-17   Wandsworth  France        NaN
#
#                                    weight_kg   died_date
# born_country born_region
# FRA          Gironde                     NaN  1960-10-02
#              Yvelines                   76.0         NaN
#              Pyrénées-Atlantiques       76.0  1994-07-17
#              Paris                      64.0  1978-03-20
# GBR          England                     NaN  1930-07-25

# %%
bios.reset_index(inplace=True)

# %% [markdown]
# ## Groub by and Aggregating

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AlexTheAnalyst/PandasYouTubeSeries/main/Flavors.csv")
df.head()
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %%
df.groupby('Base Flavor').agg({"Flavor Rating": ['mean','max','count']})
# Out:
#             Flavor Rating
#                      mean   max count
# Base Flavor
# Chocolate             8.4   8.8     3
# Vanilla               5.7  10.0     6

# %%
pd.set_option('display.max_columns', 24)

# %%
newdf = df.groupby(['Flavor','Base Flavor']).describe()
newdf
# Out:
#                                    Flavor Rating                              \
#                                            count  mean std   min   25%   50%
# Flavor                 Base Flavor
# Cake Batter            Vanilla               1.0   6.5 NaN   6.5   6.5   6.5
# Chocolate              Chocolate             1.0   8.8 NaN   8.8   8.8   8.8
# Chocolte Fudge Brownie Chocolate             1.0   8.2 NaN   8.2   8.2   8.2
# Cookie Dough           Vanilla               1.0   6.9 NaN   6.9   6.9   6.9
# Mint Chocolate Chip    Vanilla               1.0  10.0 NaN  10.0  10.0  10.0
# Neapolitan             Vanilla               1.0   3.8 NaN   3.8   3.8   3.8
# Pistachio              Vanilla               1.0   2.3 NaN   2.3   2.3   2.3
# Rocky Road             Chocolate             1.0   8.2 NaN   8.2   8.2   8.2
# Vanilla                Vanilla               1.0   4.7 NaN   4.7   4.7   4.7
#
#                                                Texture Rating                \
#                                      75%   max          count mean std  min
# Flavor                 Base Flavor
# Cake Batter            Vanilla       6.5   6.5            1.0  6.0 NaN  6.0
# Chocolate              Chocolate     8.8   8.8            1.0  7.6 NaN  7.6
# Chocolte Fudge Brownie Chocolate     8.2   8.2            1.0  7.1 NaN  7.1
# Cookie Dough           Vanilla       6.9   6.9            1.0  6.5 NaN  6.5
# Mint Chocolate Chip    Vanilla      10.0  10.0            1.0  8.0 NaN  8.0
# Neapolitan             Vanilla       3.8   3.8            1.0  5.0 NaN  5.0
# Pistachio              Vanilla       2.3   2.3            1.0  3.4 NaN  3.4
# Rocky Road             Chocolate     8.2   8.2            1.0  7.0 NaN  7.0
# Vanilla                Vanilla       4.7   4.7            1.0  5.0 NaN  5.0
#
#                                                        Total Rating            \
#                                     25%  50%  75%  max        count  mean std
# Flavor                 Base Flavor
# Cake Batter            Vanilla      6.0  6.0  6.0  6.0          1.0  12.5 NaN
# Chocolate              Chocolate    7.6  7.6  7.6  7.6          1.0  16.6 NaN
# Chocolte Fudge Brownie Chocolate    7.1  7.1  7.1  7.1          1.0  15.3 NaN
# Cookie Dough           Vanilla      6.5  6.5  6.5  6.5          1.0  13.4 NaN
# Mint Chocolate Chip    Vanilla      8.0  8.0  8.0  8.0          1.0  18.0 NaN
# Neapolitan             Vanilla      5.0  5.0  5.0  5.0          1.0   8.8 NaN
# Pistachio              Vanilla      3.4  3.4  3.4  3.4          1.0   5.7 NaN
# Rocky Road             Chocolate    7.0  7.0  7.0  7.0          1.0  15.2 NaN
# Vanilla                Vanilla      5.0  5.0  5.0  5.0          1.0   9.7 NaN
#
#
#                                      min   25%   50%   75%   max
# Flavor                 Base Flavor
# Cake Batter            Vanilla      12.5  12.5  12.5  12.5  12.5
# Chocolate              Chocolate    16.6  16.6  16.6  16.6  16.6
# Chocolte Fudge Brownie Chocolate    15.3  15.3  15.3  15.3  15.3
# Cookie Dough           Vanilla      13.4  13.4  13.4  13.4  13.4
# Mint Chocolate Chip    Vanilla      18.0  18.0  18.0  18.0  18.0
# Neapolitan             Vanilla       8.8   8.8   8.8   8.8   8.8
# Pistachio              Vanilla       5.7   5.7   5.7   5.7   5.7
# Rocky Road             Chocolate    15.2  15.2  15.2  15.2  15.2
# Vanilla                Vanilla       9.7   9.7   9.7   9.7   9.7

# %% [markdown]
# # Merging Data Frame
#
# ![image.png](attachment:image.png)

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/AlexTheAnalyst/PandasYouTubeSeries/main/LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/AlexTheAnalyst/PandasYouTubeSeries/main/LOTR%202.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
df1.merge(df2) # default how -> inner
# took the unique values
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how = 'outer')
# took all the values and used nan on blank position
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
df1.merge(df2, how='inner', on="FellowshipID") # default on = ["FellowshipID","FirstName"]
# on means based on key
# they make two firstname because this is no more a key , firstname is common so they are double
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0          1001       Frodo     Hiding       Frodo   50
# 1          1002     Samwise  Gardening     Samwise   39
